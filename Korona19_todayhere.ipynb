# %% [markdown]
# # 코로나19 감염 현황 Open API 불러오기
# - https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15043376

# %%
import urllib.request
import xml.dom.minidom

encodingKey = "xdfF98ejTww3F3VXMqIRJN3XLCSqq780bBZbDhr%2FyFofv6v6RBkthQkBJtydhaQaIirSeka%2BVDSQKqMNOkMXnQ%3D%3D"
decodingKey = "xdfF98ejTww3F3VXMqIRJN3XLCSqq780bBZbDhr/yFofv6v6RBkthQkBJtydhaQaIirSeka+VDSQKqMNOkMXnQ=="

print("[START]")

# request url정의
url = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey="  
settings = encodingKey + "&pageNo=1&numOfRows=10&startCreateDt=20200310&endCreateDt=20200315"
request = urllib.request.Request(url + settings)

# request보내기
response = urllib.request.urlopen(request)

# 결과 코드 정의
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    dom = xml.dom.minidom.parseString(response_body.decode('utf-8'))
    pretty_xml_as_string = dom.toprettyxml()
    print(pretty_xml_as_string)
else:
    print("Error Code:" + rescode)

print("[END]")

# %% [markdown]
# # 코로나19 시·도발생 현황 Open API 불러오기
# - https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15043378

# %%
import urllib.request
import xml.dom.minidom

encodingKey = "xdfF98ejTww3F3VXMqIRJN3XLCSqq780bBZbDhr%2FyFofv6v6RBkthQkBJtydhaQaIirSeka%2BVDSQKqMNOkMXnQ%3D%3D"
decodingKey = "xdfF98ejTww3F3VXMqIRJN3XLCSqq780bBZbDhr/yFofv6v6RBkthQkBJtydhaQaIirSeka+VDSQKqMNOkMXnQ=="

print("[START]")

# request url정의
url = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey="  
settings = encodingKey + "&pageNo=1&numOfRows=10&startCreateDt=20200701&endCreateDt=20200701"
request = urllib.request.Request(url + settings)

# request보내기
response = urllib.request.urlopen(request)

# 결과 코드 정의
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    dom = xml.dom.minidom.parseString(response_body.decode('utf-8'))
    pretty_xml_as_string = dom.toprettyxml()
    print(pretty_xml_as_string)
else:
    print("Error Code:" + rescode)

print("[END]")
# Out:
# [START]
# <?xml version="1.0" ?>
# <response>
# 	<header>
# 		<resultCode>00</resultCode>
# 		<resultMsg>NORMAL SERVICE.</resultMsg>
# 	</header>
# 	<body>
# 		<items>
# 			<item>
# 				<createDt>2020-07-01 10:28:45.45</createDt>
# 				<deathCnt>0</deathCnt>
# 				<defCnt>729</defCnt>
# 				<gubun>검역</gubun>
# 				<gubunCn>隔離區</gubunCn>
# 				<gubunEn>Lazaretto</gubunEn>
# 				<incDec>5</incDec>
# 				<isolClearCnt>548</isolClearCnt>
# 				<isolIngCnt>181</isolIngCnt>
# 				<localOccCnt>0</localOccCnt>
# 				<overFlowCnt>5</overFlowCnt>
# 				<qurRate>-</qurRate>
# 				<seq>2686</seq>
# 				<stdDay>2020년 07월 01일 00시</stdDay>
# 				<updateDt>NULL</updateDt>
# 			</item>
# 			<item>
# 				<createDt>2020-07-01 10:28:45.45</createDt>
# 				<deathCnt>0</deathCnt>
# 				<defCnt>19</defCnt>
# 				<gubun>제주</gubun>
# 				<gubunCn>济州</gubunCn>
# 				<gubunEn>Jeju</gubunEn>
# 				<incDec>0</incDec>
# 				<isolClearCnt>16</isolClearCnt>
# 				<isolIngCnt>3</isolIngCnt>
# ...
