# %%
import pandas as pd

df=pd.read_csv('tour.csv',encoding='CP949')
print(df[:5])
tourlist=df['관광지명']
tourlist[:10]
# Out:
#        관광지명 관광지구분                소재지도로명주소                소재지지번주소         위도  \
# 0    임진각관광지   관광지    경기도 파주시 문산읍 임진각로 177  경기도 파주시 문산읍 사목리 494-1  37.889318
# 1     공릉관광지   관광지     경기도 파주시 조리읍 장곡로 218  경기도 파주시 조리읍 장곡리 420-6  37.749811
# 2  방화동가족휴가촌   관광지   전라북도 장수군 번암면 방화동로 778   전라북도 장수군 번암면 사암리 625  35.590642
# 3     송정관광지   관광지    경상남도 남해군 미조면 미송로 483  경상남도 남해군 미조면 송정리 1129  34.723145
# 4   예당국민관광지   관광지  충청남도 예산군 응봉면 예당관광로 161                    NaN  36.638013
#
#            경도        면적                                           공공편익시설정보  \
# 0  126.740081  477894.0  관리사무실+관광안내매표소1층+화장실3동+홍보관1층+상황실2층+오수처리장1층+기반시설...
# 1  126.833566  621155.0                              관리사무소+화장실4동+도로+광장+주차장
# 2  127.526876  250000.0                          관리사무실, 주차장, 화장실, 샤워실, 취사장
# 3  128.024967  605283.0                  샤워탈의장/화장실(2동)+관리사무실(2동)+오수처리장+주차장
# 4  126.799434  143000.0                                  관리사무소+화장실(6동)+주차장
#
# ...
